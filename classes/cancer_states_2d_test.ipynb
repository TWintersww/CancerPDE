# %%
import sys
import os

sys.path.append("..")

import numpy as np
import matplotlib.pyplot as plt

from classes import CancerStates2d
from classes import CancerCell
from collections import Counter
from IPython.display import Video

# %%
# From Paper
sim = CancerStates2d(X_dim = 1, Y_dim = 1, T_dim = 1, h = 0.005, k = 0.001, dn = 0.001, dm = 0.001, l_gamma = 0.005, l_eta = 10, l_alpha = 0.1, l_beta = 0, l_epsilon = 0.0025, init_CC = 10)
# Test
# sim = CancerStates2d(X_dim = 1, Y_dim = 1, T_dim = 10, h = 0.0025, k = 0.001, dn = 0.001, dm = 0.001, l_gamma = 0.005, l_eta = 10, l_alpha = 0.1, l_beta = 0, l_epsilon = 0.0025, init_CC = 1)
sim.plot_NMF(0)
# Out:
# Instance has nx = 201, ny = 201, nt = 1001

# %%
for i in range(1, 101):
  sim.next_F(i)
  sim.next_M(i)
  sim.next_N(i)
  sim.next_N_discrete(i)
# Out:
# cell 4 undergoes mitosis
# cell 6 undergoes mitosis

# %%
sim.plot_NMF(1)

# %%
sim.plot_NMF_PowerNorm(100)

# %%
sim.plot_NMF_LogNorm(100)

# %%
sim.plot_NMF_Sobel(100)

# %%
sim.plot_NMF_Gaussian(100)

# %%
sim.plot_NMF_Comparative(0)

# %%
sim.plot_N_discrete(100)
# Out:
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101

# %%
# %%capture

if not os.path.exists('animations'):
  os.makedirs('animations')

# ani = sim.animate_NMF()
# ani.save('animations/NMF.mp4', writer='ffmpeg', fps=200)

# %%
# %%capture 

# ani = sim.animate_N()
# ani.save('animations/N.mp4', writer='ffmpeg', fps=200)
